# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshitAI51/Machine-Learning-Series/blob/main/3_working_with_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=b22048e9d06d2a6cc44f359905e5e67f8&language=en-US&page=1')

# %%
pd.DataFrame(response.json()['results']) [['id','tittle','relaese','rated']]#to convert into data frame of json data

# %%
df = pd.DataFrame()
